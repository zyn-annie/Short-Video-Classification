# %%
import cv2
import numpy as np
from skimage import data_dir,io,transform,color,filters
#coding： utf-8
import os
from PIL import Image
 
import cv2

import cv2
import numpy as np
from skimage import data_dir,io,transform,color,filters
#coding： utf-8
import os
from PIL import Image
 
import cv2

import cv2
import numpy as np
from skimage import data_dir,io,transform,color,filters
#coding： utf-8
import os
from PIL import Image

str1='F:/workspace_python/test_video/'
str2='F:/workspace_python/intest/'
str3='F:/workspace_python/train_video/'
str4='F:/workspace_python/intrain/'
def get_image(filename,str1,str2):
    cap = cv2.VideoCapture(str1+str(filename))
    filename=filename[:-4]
    fps = cap.get(cv2.CAP_PROP_FPS)  # 获取帧速
    #print(fps)
    fWidth = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
    #print(fWidth)
    fHeight = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
    #print(fHeight)
    fNums = cap.get(cv2.CAP_PROP_FRAME_COUNT)
    success,frame = cap.read()
    print(success)
    i = 0
    b = 0
    while success : 
        success,arr = cv2.imencode('.jpg', frame)
        a = arr.tostring()
        if ((i % 45)==0):
            b+=1
            fp = open(str2+ filename + str(b)+'.jpg','wb')
            fp.write(a)
            fp.close()
            
            if b==5:
                break
        success,frame = cap.read()
        i = i+1      
    cap.release()
    
if __name__ == '__main__':
    for i in os.listdir('test_video'):
        print (i)
        get_image(i,str1,str2)
    
    for i in os.listdir('train_video'):
        print (i)
        get_image(i,str3,str4)
# Out:
# 30018754.mp4
# True
# 303746162.mp4
# True
# 303771055.mp4
# True
# 303783414.mp4
# True
# 303785363.mp4
# True
# 303835132.mp4
# True
# 303860380.mp4
# True
# 303866446.mp4
# True
# 303922809.mp4
# True
# 30393422.mp4
# True
# 303942687.mp4
# True
# 303984896.mp4
# True
# 303996365.mp4
# True
# 303997720.mp4
# True
# 304028483.mp4
# True
# 304037982.mp4
# True
# 304069544.mp4
# True
# 304078846.mp4
# True
# 305345937.mp4
# True
# 306772421.mp4
# True
# 307240559.mp4
# True
# 308166809.mp4
# True
# 30884991.mp4
# True
# 310524138.mp4
# True
# 31145791.mp4
# True
# 320101153.mp4
# True
# 320717634.mp4
# True
# 322295082.mp4
# True
# 325213068.mp4
# True
# 325491436.mp4
# True
# 326999982.mp4
# True
# 329729162.mp4
# True
# 332385400.mp4
# True
# 333014934.mp4
# True
# 333157148.mp4
# True
# 333411303.mp4
# True
# 334749163.mp4
# True
# 337689228.mp4
# True
# 341676117.mp4
# True
# 344025523.mp4
# True
# 34623580.mp4
# True
# 346789577.mp4
# True
# 349118501.mp4
# True
# 351301706.mp4
# ...
